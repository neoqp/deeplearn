# %%
data_dir = "../../dataset/rsna-2024-lumbar-spine-degenerative-classification/"

import pydicom
dcm = pydicom.dcmread(str(data_dir + "train_images/4003253/1054713880/11.dcm"))

img = dcm.pixel_array

import matplotlib.pyplot as plt

plt.imshow(img, cmap=plt.cm.bone)
#print(dcm)

# %%
import os
train_list = os.listdir(data_dir + "train_images")

number_dict = set()
cnt=0
for number in train_list:
    l = len(os.listdir(data_dir + "train_images/" + number))
    number_dict.add(l)
    if l==4:
        print(number)
        cnt+=1
        break
print(cnt)
# Out:
# 1009445512
# 1

# %%
import pandas as pd

coordinates = pd.read_csv(data_dir + 'train_label_coordinates.csv')
descriptions = pd.read_csv(data_dir + 'train_series_descriptions.csv')
train = pd.read_csv(data_dir + 'train.csv')

coordinates
# study_id / series_id / instance_number / condition / level / x / y

#descriptions
# study_id / series_id / series_description (Axial T2, Sagittal T1, Sagittal T2/STIR)

#train # 각각의 요추에서의 상태가 어떤지 표현 (Normal/Mild or Moderate or Severe)
# Out:
#          study_id   series_id  instance_number  \
# 0         4003253   702807833                8
# 1         4003253   702807833                8
# 2         4003253   702807833                8
# 3         4003253   702807833                8
# 4         4003253   702807833                8
# ...           ...         ...              ...
# 48687  4290709089  4237840455               11
# 48688  4290709089  4237840455               12
# 48689  4290709089  4237840455               12
# 48690  4290709089  4237840455               12
# 48691  4290709089  4237840455               12
#
#                              condition  level           x           y
# 0                Spinal Canal Stenosis  L1/L2  322.831858  227.964602
# 1                Spinal Canal Stenosis  L2/L3  320.571429  295.714286
# 2                Spinal Canal Stenosis  L3/L4  323.030303  371.818182
# 3                Spinal Canal Stenosis  L4/L5  335.292035  427.327434
# ...

# %%
train
# Out:
#         study_id spinal_canal_stenosis_l1_l2 spinal_canal_stenosis_l2_l3  \
# 0        4003253                 Normal/Mild                 Normal/Mild
# 1        4646740                 Normal/Mild                 Normal/Mild
# 2        7143189                 Normal/Mild                 Normal/Mild
# 3        8785691                 Normal/Mild                 Normal/Mild
# 4       10728036                 Normal/Mild                 Normal/Mild
# ...          ...                         ...                         ...
# 1970  4282019580                 Normal/Mild                 Normal/Mild
# 1971  4283570761                 Normal/Mild                 Normal/Mild
# 1972  4284048608                 Normal/Mild                 Normal/Mild
# 1973  4287160193                 Normal/Mild                    Moderate
# 1974  4290709089                 Normal/Mild                 Normal/Mild
#
#      spinal_canal_stenosis_l3_l4 spinal_canal_stenosis_l4_l5  \
# ...

# %%
series_dis = descriptions[descriptions['series_description']=='Axial T2']

res = coordinates[coordinates['series_id'].isin(series_dis['series_id'])]
res = res[res['condition'] != "Spinal Canal Stenosis"]

set(res['condition'])

#  Sagittal T2/STIR => Spinal Canal Stenosis 판별용
#  Sagittal T1      => L/R Neural Foraminal Narrowing 판별용
#  Axial T2         => L/R Subarticular Stenosis 판별용
# Out:
# {'Left Subarticular Stenosis', 'Right Subarticular Stenosis'}
